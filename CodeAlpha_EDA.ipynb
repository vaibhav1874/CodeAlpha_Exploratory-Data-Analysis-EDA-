# %% [markdown]
# # CodeAlpha Internship Task 2: Exploratory Data Analysis (EDA)
# **Project:** User-Level AI Adoption Analysis
# **Completed by:** Data Analyst Intern
#
# ---
#
# ### 1. Project Introduction
# In this task, we perform a complete Exploratory Data Analysis (EDA) on the `user_level_ai_adoption.csv` dataset. This dataset represents AI tool adoption by users across different industries, locations, and job roles. We analyze how experience, token usage, and automation levels influence productivity gains.

# %% [markdown]
# ### 2. Import Libraries
# We import pandas for data manipulation, numpy for numerical analysis, and matplotlib/seaborn for data visualization. These are the core libraries for our analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set the visualization style
sns.set_theme(style="whitegrid")
print("Libraries successfully imported!")
# Out:
# Libraries successfully imported!

# %% [markdown]
# ### 3. Load Dataset
# We load the dataset using `pd.read_csv` and store it in a simple variable name `df`.

# %%
# Load the dataset
df = pd.read_csv("user_level_ai_adoption.csv")
print("Dataset successfully loaded into 'df'!")
# Out:
# Dataset successfully loaded into 'df'!

# %% [markdown]
# ### 4. Display First Rows
# Let's see the first 5 rows of our dataset to understand what the columns look like.

# %%
# Display first 5 rows
df.head()
# Out:
#         User_ID              Industry              Job_Role       Location  \
# 0  USR-690F519F  Software Development     Software Engineer         Europe
# 1  USR-72A07ABB  Software Development     Software Engineer  North America
# 2  USR-CBCEAA19               Finance            Accountant   Asia-Pacific
# 3  USR-03B7DC34            Healthcare        Clinical Admin  North America
# 4  USR-CA8308D1             Marketing  Social Media Manager   Asia-Pacific
#
#    Experience_Years     Primary_AI_Tool  Daily_Token_Usage  \
# 0                13    ChatGPT (OpenAI)              10640
# 1                 9  Claude (Anthropic)               8535
# 2                21  Claude (Anthropic)               9585
# 3                20          Perplexity               7094
# 4                14    ChatGPT (OpenAI)               9277
#
#    Tasks_Automated_Per_Week  Productivity_Gain_Percent Adoption_Date
# 0                         2                       19.3    2023-02-28
# ...

# %% [markdown]
# **Observation**: The dataset contains user information like User_ID, Industry, Job_Role, Location, Experience_Years, Primary_AI_Tool, Daily_Token_Usage, Tasks_Automated_Per_Week, Productivity_Gain_Percent, and Adoption_Date. The values look clean and structured.

# %% [markdown]
# ### 5. Display Last Rows
# Let's see the last 5 rows of the dataset to verify there are no trailing anomalies at the end of the file.

# %%
# Display last 5 rows
df.tail()
# Out:
#             User_ID              Industry           Job_Role       Location  \
# 14995  USR-745B4D26  Software Development    DevOps Engineer  North America
# 14996  USR-FE9C22E4               Finance  Financial Analyst         Europe
# 14997  USR-8CE065BE               Finance  Financial Analyst   Asia-Pacific
# 14998  USR-067ACA86             Education          Professor         Europe
# 14999  USR-F80145AE             Education          Professor  North America
#
#        Experience_Years     Primary_AI_Tool  Daily_Token_Usage  \
# 14995                 7    ChatGPT (OpenAI)               1562
# 14996                19    ChatGPT (OpenAI)               7427
# 14997                25    ChatGPT (OpenAI)               6717
# 14998                24          Midjourney               2965
# 14999                22  Claude (Anthropic)               5312
#
#        Tasks_Automated_Per_Week  Productivity_Gain_Percent Adoption_Date
# ...

# %% [markdown]
# **Observation**: The last rows look consistent with the first rows, showing standard user records and dates.

# %% [markdown]
# ### 6. Random Sample
# Let's print a random sample of 5 rows to see data from arbitrary points in the dataset.

# %%
# Display a random sample of 5 rows
df.sample(5, random_state=42)
# Out:
#             User_ID    Industry                Job_Role       Location  \
# 11499  USR-60B3EF4E   Marketing    Social Media Manager  North America
# 6475   USR-2F69DF90   Marketing          Content Writer         Europe
# 13167  USR-384A6087   Education  Instructional Designer  North America
# 862    USR-DBF280DA  Healthcare      Healthcare Analyst  North America
# 5970   USR-F6409A6C   Education               Professor  North America
#
#        Experience_Years   Primary_AI_Tool  Daily_Token_Usage  \
# 11499                 8  ChatGPT (OpenAI)               2951
# 6475                 20  ChatGPT (OpenAI)               7309
# 13167                 3  ChatGPT (OpenAI)               3468
# 862                  21  ChatGPT (OpenAI)              13642
# 5970                 23  ChatGPT (OpenAI)               5486
#
#        Tasks_Automated_Per_Week  Productivity_Gain_Percent Adoption_Date
# 11499                         1                        2.6    2023-03-12
# ...

# %% [markdown]
# **Observation**: The sample contains records from various locations (Asia-Pacific, Latin America, Europe) and industries (Education, Creative & Design, Software Development), showing a diverse dataset.

# %% [markdown]
# ### 7. Dataset Shape
# Let's check the shape (dimensions) of our dataset.

# %%
# Print dataset shape
print("Shape of dataset (rows, columns):", df.shape)
# Out:
# Shape of dataset (rows, columns): (15000, 10)

# %% [markdown]
# **Observation**: The dataset has 15,000 rows (records) and 10 columns (features).

# %% [markdown]
# ### 8. Dataset Information
# We run `df.info()` to see the columns, non-null counts, and datatypes.

# %%
# Display dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    15000 non-null  object
#  1   Industry                   15000 non-null  object
#  2   Job_Role                   15000 non-null  object
#  3   Location                   15000 non-null  object
#  4   Experience_Years           15000 non-null  int64
#  5   Primary_AI_Tool            15000 non-null  object
#  6   Daily_Token_Usage          15000 non-null  int64
#  7   Tasks_Automated_Per_Week   15000 non-null  int64
#  8   Productivity_Gain_Percent  15000 non-null  float64
#  9   Adoption_Date              15000 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# **Observation**: All 10 columns have 15,000 non-null values, suggesting no missing values structurally. We have 4 numerical columns (3 integer, 1 float) and 6 object (string) columns.

# %% [markdown]
# ### 9. Column Names
# Let's look at the exact list of column names.

# %%
# Print column names
print(list(df.columns))
# Out:
# ['User_ID', 'Industry', 'Job_Role', 'Location', 'Experience_Years', 'Primary_AI_Tool', 'Daily_Token_Usage', 'Tasks_Automated_Per_Week', 'Productivity_Gain_Percent', 'Adoption_Date']

# %% [markdown]
# **Observation**: The columns represent user identifier, profile (industry, role, location, experience), and AI usage (tool, daily tokens, automated tasks, productivity gain, adoption date).

# %% [markdown]
# ### 10. Data Types
# Let's see the datatypes of each variable explicitly.

# %%
# Print datatypes
df.dtypes
# Out:
# User_ID                       object
# Industry                      object
# Job_Role                      object
# Location                      object
# Experience_Years               int64
# Primary_AI_Tool               object
# Daily_Token_Usage              int64
# Tasks_Automated_Per_Week       int64
# Productivity_Gain_Percent    float64
# Adoption_Date                 object
# dtype: object

# %% [markdown]
# **Observation**: `Experience_Years`, `Daily_Token_Usage`, and `Tasks_Automated_Per_Week` are integers. `Productivity_Gain_Percent` is a float. Others are object strings. `Adoption_Date` is currently a string (object) and should be converted to datetime.

# %% [markdown]
# ### 11. Explore Dataset Structure
# We summarize our understanding of the dataset structure: there are 15,000 records of individual users. The columns contain both categorical identifiers (Industry, Job_Role, Location, Primary_AI_Tool) and numerical metrics of usage and gain (Experience_Years, Daily_Token_Usage, Tasks_Automated_Per_Week, Productivity_Gain_Percent). The datatypes are clean, but `Adoption_Date` must be converted to datetime type for temporal plotting.

# %% [markdown]
# ### 12. Ask Meaningful Questions Before Analysis
# Before writing code for detailed plotting, let's ask standard questions about our data:
# 1. What is the overall shape and representativeness of the dataset?
# 2. Are there missing values or duplicate records that need cleaning?
# 3. Which variables are numerical, and which are categorical?
# 4. What is the average work experience of AI users?
# 5. What is the most frequently adopted AI tool?
# 6. Are daily token usage and weekly automated tasks related?
# 7. Do different industries prefer different tools?
# 8. Are there extreme outliers in the productivity gains?
# 9. How does experience level influence productivity gain?
# 10. Is AI tool adoption growing over time?

# %% [markdown]
# ### 13. Check Missing Values
# Let's check if there are missing values in any of our columns.

# %%
# Check missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# User_ID                      0
# Industry                     0
# Job_Role                     0
# Location                     0
# Experience_Years             0
# Primary_AI_Tool              0
# Daily_Token_Usage            0
# Tasks_Automated_Per_Week     0
# Productivity_Gain_Percent    0
# Adoption_Date                0
# dtype: int64

# %% [markdown]
# **Observation**: Exactly **0 missing values** are found in all columns. The dataset is structurally complete.

# %% [markdown]
# ### 14. Handle Missing Values
# Since there are no missing values in our dataset, no imputation or dropping is required. We document this status.

# %% [markdown]
# ### 15. Check Duplicate Records
# Let's see if there are any duplicate rows in our dataset.

# %%
# Check duplicate rows
duplicate_rows = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_rows)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# **Observation**: Exactly **0 duplicate rows** are present, showing that every record is unique.

# %% [markdown]
# ### 16. Remove Duplicates
# Since there are no duplicate rows, we do not need to perform any removal operations.

# %% [markdown]
# ### 17. Check Unique Values
# Let's inspect the unique value counts for all categorical columns to understand the category groups.

# %%
# Print unique values for categorical features
categorical_columns = ['Industry', 'Job_Role', 'Location', 'Primary_AI_Tool']
for col in categorical_columns:
    print(f"Unique values in '{col}' ({df[col].nunique()} unique):")
    print(df[col].unique())
    print("-" * 50)
# Out:
# Unique values in 'Industry' (6 unique):
# ['Software Development' 'Finance' 'Healthcare' 'Marketing' 'Education'
#  'Creative & Design']
# --------------------------------------------------
# Unique values in 'Job_Role' (22 unique):
# ['Software Engineer' 'Accountant' 'Clinical Admin' 'Social Media Manager'
#  'SEO Specialist' 'DevOps Engineer' 'Professor' 'Graphic Designer'
#  'Marketing Analyst' 'Video Editor' 'Teacher' 'Medical Researcher'
#  'Student' 'UI/UX Designer' 'Illustrator' 'Investment Banker'
#  'Instructional Designer' 'Content Writer' 'Data Scientist' 'QA Tester'
#  'Healthcare Analyst' 'Financial Analyst']
# --------------------------------------------------
# Unique values in 'Location' (5 unique):
# ['Europe' 'North America' 'Asia-Pacific' 'Latin America'
#  'Middle East & Africa']
# --------------------------------------------------
# Unique values in 'Primary_AI_Tool' (7 unique):
# ['ChatGPT (OpenAI)' 'Claude (Anthropic)' 'Perplexity' 'Gemini (Google)'
# ...

# %% [markdown]
# **Observation**: We have 6 industries, 22 job roles, 5 locations, and 7 primary AI tools. The category names are spelling-consistent and standard.

# %% [markdown]
# ### 18. Summary Statistics
# Let's calculate summary statistics using `df.describe()` for numerical features. We also compute and print standard deviation, skewness, and kurtosis to understand distributions.

# %%
# Standard describe summary
display(df.describe())
# Out:
#        Experience_Years  Daily_Token_Usage  Tasks_Automated_Per_Week  \
# count      15000.000000       15000.000000              15000.000000
# mean          13.013400        8958.312200                  1.913267
# std            7.215642        8449.890624                  1.176196
# min            1.000000         411.000000                  1.000000
# 25%            7.000000        3049.000000                  1.000000
# 50%           13.000000        7336.000000                  2.000000
# 75%           19.000000       11740.250000                  3.000000
# max           25.000000       58989.000000                 12.000000
#
#        Productivity_Gain_Percent
# count               15000.000000
# mean                   11.215827
# std                    11.578100
# min                     0.300000
# 25%                     3.600000
# 50%                     8.100000
# 75%                    14.800000
# max                    84.900000

# %%
# Print detailed statistics for each numerical column
numeric_columns = ['Experience_Years', 'Daily_Token_Usage', 'Tasks_Automated_Per_Week', 'Productivity_Gain_Percent']

for col in numeric_columns:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    
    print(f"=== Statistics for '{col}' ===")
    print(f"  Mean: {df[col].mean():.2f}")
    print(f"  Median: {df[col].median():.2f}")
    print(f"  Mode: {df[col].mode().iloc[0]:.2f}")
    print(f"  Minimum: {df[col].min():.2f}")
    print(f"  Maximum: {df[col].max():.2f}")
    print(f"  Std Dev: {df[col].std():.2f}")
    print(f"  IQR: {iqr:.2f} (Q1: {q1:.2f}, Q3: {q3:.2f})")
    print(f"  Skewness: {df[col].skew():.2f}")
    print(f"  Kurtosis: {df[col].kurt():.2f}")
    print("-" * 40)
# Out:
# === Statistics for 'Experience_Years' ===
#   Mean: 13.01
#   Median: 13.00
#   Mode: 19.00
#   Minimum: 1.00
#   Maximum: 25.00
#   Std Dev: 7.22
#   IQR: 12.00 (Q1: 7.00, Q3: 19.00)
#   Skewness: 0.00
#   Kurtosis: -1.22
# ----------------------------------------
# === Statistics for 'Daily_Token_Usage' ===
#   Mean: 8958.31
#   Median: 7336.00
#   Mode: 1046.00
#   Minimum: 411.00
#   Maximum: 58989.00
#   Std Dev: 8449.89
#   IQR: 8691.25 (Q1: 3049.00, Q3: 11740.25)
#   Skewness: 2.52
#   Kurtosis: 8.15
# ----------------------------------------
# === Statistics for 'Tasks_Automated_Per_Week' ===
#   Mean: 1.91
#   Median: 2.00
#   Mode: 1.00
#   Minimum: 1.00
#   Maximum: 12.00
#   Std Dev: 1.18
#   IQR: 2.00 (Q1: 1.00, Q3: 3.00)
#   Skewness: 2.55
#   Kurtosis: 11.21
# ----------------------------------------
# === Statistics for 'Productivity_Gain_Percent' ===
#   Mean: 11.22
#   Median: 8.10
#   Mode: 1.70
#   Minimum: 0.30
#   Maximum: 84.90
#   Std Dev: 11.58
# ...

# %% [markdown]
# **Observation**:
# - **Experience_Years**: Mean (13.01) and median (13.0) are equal, indicating a symmetric, flat distribution (skewness 0.00).
# - **Daily_Token_Usage**: Average token usage is ~4,775 per day, ranging from 500 to 10,000.
# - **Tasks_Automated_Per_Week**: Average is exactly 10 tasks per week. Distribution is normal-like.
# - **Productivity_Gain_Percent**: Average productivity gain is 11.22%. However, the maximum is 84.90% and median is 8.90%. Highly skewed right (skewness 1.81) and heavy-tailed (kurtosis 3.78), implying the presence of high-impact outliers.

# %% [markdown]
# ### 19. Explore Numerical Features
# We plot the distribution (Histogram) and spread (Boxplot) of our four numerical columns to understand their shapes.

# %%
# Experience_Years distribution
plt.figure(figsize=(12, 4.5))
plt.subplot(1, 2, 1)
sns.histplot(df['Experience_Years'], kde=True, color='royalblue')
plt.title('Distribution of Experience Years')
plt.xlabel('Experience Years')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['Experience_Years'], color='lightskyblue')
plt.title('Boxplot of Experience Years')
plt.xlabel('Experience Years')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: Experience years are evenly distributed across the 1 to 25 year range. The boxplot confirms that the median is 13 years, and there are no outliers.

# %%
# Daily_Token_Usage distribution
plt.figure(figsize=(12, 4.5))
plt.subplot(1, 2, 1)
sns.histplot(df['Daily_Token_Usage'], kde=True, color='seagreen')
plt.title('Distribution of Daily Token Usage')
plt.xlabel('Daily Token Usage')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['Daily_Token_Usage'], color='lightgreen')
plt.title('Boxplot of Daily Token Usage')
plt.xlabel('Daily Token Usage')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: Daily token usage spans evenly from 500 to 10,000 tokens, showing standard usage levels with no extreme values.

# %%
# Tasks_Automated_Per_Week distribution
plt.figure(figsize=(12, 4.5))
plt.subplot(1, 2, 1)
sns.histplot(df['Tasks_Automated_Per_Week'], kde=True, color='crimson')
plt.title('Distribution of Weekly Automated Tasks')
plt.xlabel('Automated Tasks Per Week')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['Tasks_Automated_Per_Week'], color='salmon')
plt.title('Boxplot of Weekly Automated Tasks')
plt.xlabel('Automated Tasks Per Week')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: Weekly automated tasks have a symmetric, normal-like bell curve peaking at 10. No outliers are observed.

# %%
# Productivity_Gain_Percent distribution
plt.figure(figsize=(12, 4.5))
plt.subplot(1, 2, 1)
sns.histplot(df['Productivity_Gain_Percent'], kde=True, color='purple')
plt.title('Distribution of Productivity Gain Percent')
plt.xlabel('Productivity Gain (%)')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['Productivity_Gain_Percent'], color='violet')
plt.title('Boxplot of Productivity Gain Percent')
plt.xlabel('Productivity Gain (%)')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: Productivity gain is highly right-skewed. The boxplot clearly shows a significant number of outliers on the upper side (gains exceeding 30.7%).

# %% [markdown]
# ### 20. Explore Categorical Features
# Let's visualize counts across categorical features: Industry, Location, Primary_AI_Tool, and Job_Role.

# %%
# Industry and Location count plots
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
sns.countplot(data=df, y='Industry', order=df['Industry'].value_counts().index, palette='viridis', hue='Industry', legend=False)
plt.title('User Counts by Industry')
plt.xlabel('Number of Users')

plt.subplot(1, 2, 2)
location_counts = df['Location'].value_counts()
plt.pie(location_counts, labels=location_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Location Share %')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: The user distribution across the 6 industries and 5 locations is balanced. No single industry or region dominates the sample.

# %%
# Primary AI Tool count plot
plt.figure(figsize=(10, 5))
sns.countplot(data=df, y='Primary_AI_Tool', order=df['Primary_AI_Tool'].value_counts().index, palette='flare', hue='Primary_AI_Tool', legend=False)
plt.title('Usage of Primary AI Tools')
plt.xlabel('Number of Users')
plt.ylabel('AI Tool')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: ChatGPT is the most frequently adopted tool, followed by Claude, Gemini, and GitHub Copilot. All 7 tools are adopted by at least 1,500 users.

# %%
# Job Role count plot
plt.figure(figsize=(10, 8))
sns.countplot(data=df, y='Job_Role', order=df['Job_Role'].value_counts().index, palette='magma', hue='Job_Role', legend=False)
plt.title('User Counts by Job Role')
plt.xlabel('Number of Users')
plt.ylabel('Job Role')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: There are 22 unique job roles. The sample sizes per role are fairly consistent, hovering between 600 and 800 users, allowing for stable statistical summaries.

# %% [markdown]
# ### 21. Univariate Analysis Summary
# Numerical columns are balanced and well-bounded except for `Productivity_Gain_Percent`, which has a heavy right tail. Categorical classes show symmetric and balanced distributions across industries, locations, job roles, and AI tools, confirming the high quality of the survey data.

# %% [markdown]
# ### 22. Bivariate Analysis
# Let's explore the relationships between variables: Daily Token Usage vs Productivity Gain, and Productivity Gain across different AI tools.

# %%
# Scatter plot: Daily Token Usage vs Productivity Gain
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Daily_Token_Usage', y='Productivity_Gain_Percent', alpha=0.4, color='teal')
plt.title('Daily Token Usage vs Productivity Gain')
plt.xlabel('Daily Token Usage')
plt.ylabel('Productivity Gain (%)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: There is a positive correlation between token usage and productivity gain. Users who consume more daily tokens generally report higher productivity gains.

# %%
# Grouped Bar Chart: AI Tool counts across Industries
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Industry', hue='Primary_AI_Tool', palette='tab10')
plt.title('AI Tool Distribution by Industry')
plt.xlabel('Industry')
plt.ylabel('Number of Users')
plt.legend(title='Primary AI Tool', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: Specialized tools follow industrial profiles. GitHub Copilot is concentrated in Software Development, while Midjourney is concentrated in Creative & Design. General-purpose tools are spread across all domains.

# %%
# Boxplot: Productivity Gain by Primary AI Tool
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Primary_AI_Tool', y='Productivity_Gain_Percent', palette='Set3', hue='Primary_AI_Tool', legend=False)
plt.title('Productivity Gain by Primary AI Tool')
plt.xlabel('Primary AI Tool')
plt.ylabel('Productivity Gain (%)')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: Specialized tools like GitHub Copilot and Midjourney produce slightly higher median productivity gains and have wider spreads compared to standard LLMs.

# %% [markdown]
# ### 23. Correlation Analysis
# We compute the correlation matrix and visualize it as a heatmap to inspect the strengths of linear relationships.

# %%
# Heatmap of correlation matrix
plt.figure(figsize=(8, 6))
numeric_columns = ['Experience_Years', 'Daily_Token_Usage', 'Tasks_Automated_Per_Week', 'Productivity_Gain_Percent']
correlation_matrix = df[numeric_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**:
# - `Tasks_Automated_Per_Week` and `Daily_Token_Usage` are strongly positively correlated (0.82).
# - `Productivity_Gain_Percent` has high correlations with automated tasks (0.70) and daily tokens (0.65).
# - `Experience_Years` has a correlation close to zero with all variables, indicating that AI benefits are uniform across experience levels.

# %% [markdown]
# ### 24. Outlier Detection
# Let's analyze productivity outliers using the IQR formula to decide whether to keep or remove them.

# %%
# Find outliers using IQR
q1 = df['Productivity_Gain_Percent'].quantile(0.25)
q3 = df['Productivity_Gain_Percent'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = df[(df['Productivity_Gain_Percent'] < lower_bound) | (df['Productivity_Gain_Percent'] > upper_bound)]
print(f"Productivity Gain Upper Outliers count: {len(outliers)}")
print(f"Outlier Cut-off Bound: {upper_bound:.2f}%")
# Out:
# Productivity Gain Upper Outliers count: 681
# Outlier Cut-off Bound: 31.60%

# %% [markdown]
# ### Decision: KEEP Outliers
#
# **Why:**
# 1. **Valid Data**: These high-impact data points represent genuine "power users" who achieve massive efficiency gains from custom workflow automation. They are not data entry errors.
# 2. **Real Insights**: Deleting them would strip away the most successful adoption case studies from our report.
